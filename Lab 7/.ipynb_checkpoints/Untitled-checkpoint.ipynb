# %% [raw]
# import numpy as np
# import spacy
#
# # Need to load the large model to get the vectors
# nlp = spacy.load("en_core_web_sm")

# %% [raw]
# # Disabling other pipes because we don't need them and it'll speed up this part a bit
# text = "These vectors can be used as features for machine learning models."
# with nlp.disable_pipes():
#     vectors = np.array([token.vector for token in  nlp(text)])

# %% [raw]
# print(vectors)

# %% [markdown]
# https://stackoverflow.com/questions/50747947/embedding-in-pytorch

# %%
from collections import Counter
import torch.nn as nn
import torch

# Let's say you have 2 sentences(lowercased, punctuations removed) :
sentences = "i am new to PyTorch i am having fun"

words = sentences.split(' ')
print(words)
vocab = Counter(words) # create a dictionary
vocab = sorted(vocab, key=vocab.get, reverse=True)
print(vocab)
vocab_size = len(vocab)

# map words to unique indices
word2idx = {word: ind for ind, word in enumerate(vocab)}
# word2idx = {'i': 0, 'am': 1, 'new': 2, 'to': 3, 'pytorch': 4, 'having': 5, 'fun': 6}

encoded_sentences = [word2idx[word] for word in words]
# encoded_sentences = [0, 1, 2, 3, 4, 0, 1, 5, 6]

# let's say you want embedding dimension to be 3
emb_dim = 3
# Out:
# ['i', 'am', 'new', 'to', 'PyTorch', 'i', 'am', 'having', 'fun']
# ['i', 'am', 'new', 'to', 'PyTorch', 'having', 'fun']

# %%
emb_layer = nn.Embedding(vocab_size, emb_dim)
word_vectors = emb_layer(torch.LongTensor(encoded_sentences))

# %%
emb_layer
# Out:
# Embedding(7, 3)

# %%
word_vectors
# Out:
# tensor([[-0.6298, -0.4640,  0.4956],
#         [-0.4896,  0.6888,  0.8869],
#         [-0.7481,  1.5041, -0.8545],
#         [ 1.2306, -0.0431, -0.9094],
#         [ 0.0815, -0.9193, -1.5131],
#         [-0.6298, -0.4640,  0.4956],
#         [-0.4896,  0.6888,  0.8869],
#         [ 1.3327,  1.2970, -0.1171],
#         [-0.2693,  0.4487,  0.1947]], grad_fn=<EmbeddingBackward>)

# %%
emb_layer.weight.requires_grad = False

# %%
emb_layer.weight.requires_grad
# Out:
# False

# %%
emb_layer = nn.Embedding(10000, 300)
emb_layer.load_state_dict({'weight': torch.from_numpy(emb_mat)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10372/3680129169.py in <module>
#       1 emb_layer = nn.Embedding(10000, 300)
# ----> 2 emb_layer.load_state_dict({'weight': torch.from_numpy(emb_mat)})
#
# NameError: name 'emb_mat' is not defined
