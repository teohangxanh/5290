# %%
# %matplotlib inline

import spacy
import torch
import torchtext
from torchtext import data
from torchtext.datasets import text_classification


max_seq_len = 50
TEXT = data.Field(tokenize=spacy.load("en_core_web_sm"), batch_first=True, include_lengths=True, fix_length=max_seq_len)
LABEL = data.LabelField(dtype=torch.float, batch_first=True)
