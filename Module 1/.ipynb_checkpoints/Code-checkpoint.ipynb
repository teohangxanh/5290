# %%
from bs4 import BeautifulSoup
import urllib.request
import nltk
from nltk.corpus import stopwords

# https://en.wikipedia.org/wiki/SpaceX

# get html
response = urllib.request.urlopen('https://en.wikipedia.org/wiki/SpaceX')

html = response.read()

soup = BeautifulSoup(html,"html5lib")

# get text
text = soup.get_text(strip=True)

# get tokens
tokens = [t for t in text.split()]
# create distribution of top 10
freq = nltk.FreqDist(tokens)

freq.plot(10, cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# get list of top 10 tokens
values = list(freq.items())
des_values = sorted(values, key=lambda x: x[1], reverse=True)[:10]
asc_values = sorted(values, key=lambda x: x[1], reverse=False)[2:12]

# %%
import matplotlib.pyplot as plt

def plot_values(values):
    # create values for bar chart
    x = range(1, len(values) + 1)
    labels = [tup[0] for tup in values]
    y = [tup[1] for tup in values]

    # plot and rotate ticks
    plt.bar(x, y, tick_label=labels)
    plt.xticks(rotation=45)

# %%
plot_values(des_values)

# %%
plot_values(asc_values)
